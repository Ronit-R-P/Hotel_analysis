# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('F:\Documents\SQL\hotel_bookings 2.csv')

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# %%
df.describe(include = 'object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
for col in df.describe(include = 'object').columns:
    print(col)
    print(df[col].unique())
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
#  'CMR' 'BIH' 'MUS' 'COM' 'SUR' 'UGA' 'BGR' 'CIV' 'JOR' 'SYR' 'SGP' 'BDI'
#  'SAU' 'VNM' 'PLW' 'QAT' 'EGY' 'PER' 'MLT' 'MWI' 'ECU' 'MDG' 'ISL' 'UZB'
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.drop(['company','agent'],axis = 1, inplace = True)
df.dropna(inplace = True)

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483168     106.903309           0.707459
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
df = df[df['adr']>0]

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 6       Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2                    July                        27
# 3                    July                        27
# ...

# %%
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Filter for cancelled reservations
cancelled_df = df[df['is_canceled'] == 1]

# Calculate the total number of cancellations
total_cancellations = cancelled_df['is_canceled'].count()

# Normalize the cancellations
# Normalize by dividing each count by the total number of cancellations
normalized_cancellations = total_cancellations / df['is_canceled'].count()

# Display the result
print(f'Total Cancellations: {total_cancellations}')
print(f'Normalized Cancellations: {normalized_cancellations}')
# Out:
# Total Cancellations: 43950
# Normalized Cancellations: 0.3757727066749887

# %%
cancelled_resever = df['is_canceled'].value_counts(normalize = True)
cancelled_resever

plt.figure(figsize = (6,5))
plt.title('Reservation status count')
plt.bar(['Not canceled','Canceled'],df['is_canceled'].value_counts(), edgecolor = 'r', width = 0.76)
plt.show()

# %%
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Filter for cancelled and non-cancelled reservations
cancelled_df = df[df['is_canceled'] == 1]
non_cancelled_df = df[df['is_canceled'] == 0]

# Calculate the total number of cancellations and non-cancellations
total_cancellations = cancelled_df['is_canceled'].count()
total_non_cancellations = non_cancelled_df['is_canceled'].count()

# Normalize the cancellations and non-cancellations
normalized_cancellations = total_cancellations / df['is_canceled'].count()
normalized_non_cancellations = total_non_cancellations / df['is_canceled'].count()

# Display the results
print(f'Total Cancellations: {total_cancellations}')
print(f'Normalized Cancellations: {normalized_cancellations}')
print(f'Total Non-Cancellations: {total_non_cancellations}')
print(f'Normalized Non-Cancellations: {normalized_non_cancellations}')
# Out:
# Total Cancellations: 43950
# Normalized Cancellations: 0.3757727066749887
# Total Non-Cancellations: 73009
# Normalized Non-Cancellations: 0.6242272933250114

# %%
plt.figure(figsize = (8,4))
ax1 = sns.countplot(x = 'hotel', hue = 'is_canceled', data = df, palette = 'Blues')
legend_labels,_ = ax1.get_legend_handles_labels()
plt.title('Reservation status in different hotels', size = 20)
plt.xlabel('hotel')
plt.ylabel('number of reservation')
plt.legend(['not_canceled','canceled'])
plt.show()

# %%
# Group by hotel type and sum cancellations
cancellations = df.groupby('hotel')['is_canceled'].sum()

# Calculate total reservations per hotel type
total_reservations = df.groupby('hotel')['is_canceled'].count()

# Normalize cancellations
normalized_cancellations = cancellations / total_reservations

# Display the results
result = pd.DataFrame({'total_cancellations': cancellations, 'normalized_cancellations': normalized_cancellations})
print(result)
# Out:
#               total_cancellations  normalized_cancellations
# hotel
# City Hotel                  32955                  0.421948
# Resort Hotel                10995                  0.282961

# %%
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Filter data for City Hotel and Resort Hotel
city_hotel_data = df[df['hotel'] == 'City Hotel']
resort_hotel_data = df[df['hotel'] == 'Resort Hotel']

# Calculate total bookings for each hotel type
total_bookings_city_hotel = city_hotel_data.shape[0]
total_bookings_resort_hotel = resort_hotel_data.shape[0]

# Calculate total cancellations for each hotel type
total_cancellations_city_hotel = city_hotel_data[city_hotel_data['is_canceled'] == 1].shape[0]
total_cancellations_resort_hotel = resort_hotel_data[resort_hotel_data['is_canceled'] == 1].shape[0]

# Normalize the cancellations
normalized_cancellations_city_hotel = total_cancellations_city_hotel / total_bookings_city_hotel
normalized_cancellations_resort_hotel = total_cancellations_resort_hotel / total_bookings_resort_hotel

# Display the results
print(f'Total Bookings in City Hotel: {total_bookings_city_hotel}')
print(f'Total Cancellations in City Hotel: {total_cancellations_city_hotel}')
print(f'Normalized Cancellations in City Hotel: {normalized_cancellations_city_hotel}')

print(f'Total Bookings in Resort Hotel: {total_bookings_resort_hotel}')
print(f'Total Cancellations in Resort Hotel: {total_cancellations_resort_hotel}')
print(f'Normalized Cancellations in Resort Hotel: {normalized_cancellations_resort_hotel}')
# Out:
# Total Bookings in City Hotel: 78102
# Total Cancellations in City Hotel: 32955
# Normalized Cancellations in City Hotel: 0.4219482215564262
# Total Bookings in Resort Hotel: 38857
# Total Cancellations in Resort Hotel: 10995
# Normalized Cancellations in Resort Hotel: 0.2829605991198497

# %%
# Group by reservation status date and hotel, then calculate the mean ADR
grouped_data = df.groupby(['reservation_status_date', 'hotel'])['adr'].mean().reset_index()

# Display the results
print(grouped_data)
# Out:
#      reservation_status_date         hotel         adr
# 0                 2014-10-17    City Hotel   62.800000
# 1                 2015-01-01    City Hotel   62.063158
# 2                 2015-01-01  Resort Hotel   61.966667
# 3                 2015-01-02  Resort Hotel  154.140000
# 4                 2015-01-20    City Hotel   76.500000
# ...                      ...           ...         ...
# 1770              2017-09-08  Resort Hotel  101.012500
# 1771              2017-09-09  Resort Hotel  147.778333
# 1772              2017-09-10  Resort Hotel  145.272500
# 1773              2017-09-12  Resort Hotel  153.570000
# 1774              2017-09-14  Resort Hotel  105.930000
#
# [1775 rows x 3 columns]

# %%
# Filter data for City Hotel
city_hotel_data = df[df['hotel'] == 'City Hotel']
grouped_city_hotel_data = city_hotel_data.groupby('reservation_status_date')['adr'].mean().reset_index()

# Filter data for Resort Hotel
resort_hotel_data = df[df['hotel'] == 'Resort Hotel']
grouped_resort_hotel_data = resort_hotel_data.groupby('reservation_status_date')['adr'].mean().reset_index()

# Display the results
print("Grouped Data for City Hotel:")
print(grouped_city_hotel_data)

print("\nGrouped Data for Resort Hotel:")
print(grouped_resort_hotel_data)
# Out:
# Grouped Data for City Hotel:
#     reservation_status_date         adr
# 0                2014-10-17   62.800000
# 1                2015-01-01   62.063158
# 2                2015-01-20   76.500000
# 3                2015-01-30   61.400000
# 4                2015-02-17   76.500000
# ..                      ...         ...
# 859              2017-09-03  137.172600
# 860              2017-09-04  116.925385
# 861              2017-09-05  154.000000
# 862              2017-09-06   93.293333
# 863              2017-09-07  159.685000
#
# [864 rows x 2 columns]
#
# Grouped Data for Resort Hotel:
#     reservation_status_date         adr
# 0                2015-01-01   61.966667
# 1                2015-01-02  154.140000
# 2                2015-01-21   37.301209
# 3                2015-01-22  116.568333
# 4                2015-01-28  244.000000
# ..                      ...         ...
# 906              2017-09-08  101.012500
# 907              2017-09-09  147.778333
# ...

# %%
import matplotlib.pyplot as plt

# Visualizing City Hotel
plt.figure(figsize=(20, 2))
plt.plot(grouped_city_hotel_data['reservation_status_date'], grouped_city_hotel_data['adr'], label='City Hotel ADR')
plt.xlabel('Reservation Status Date', fontsize=30)
plt.ylabel('Mean ADR', fontsize=30)
plt.title('City Hotel ADR over Time', fontsize=30)
plt.legend(fontsize=20)
plt.xticks(rotation=45)
plt.show()

# Visualizing Resort Hotel
plt.figure(figsize=(20, 2))
plt.plot(grouped_resort_hotel_data['reservation_status_date'], grouped_resort_hotel_data['adr'], label='Resort Hotel ADR', color='orange')
plt.xlabel('Reservation Status Date', fontsize=30)
plt.ylabel('Mean ADR', fontsize=30)
plt.title('Resort Hotel ADR over Time', fontsize=30)
plt.legend(fontsize=20)
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

# Combine both City Hotel and Resort Hotel ADRs into a single plot
plt.figure(figsize=(20, 10))  # Increased height
plt.plot(grouped_city_hotel_data['reservation_status_date'], grouped_city_hotel_data['adr'], label='City Hotel ADR', color='blue')
plt.plot(grouped_resort_hotel_data['reservation_status_date'], grouped_resort_hotel_data['adr'], label='Resort Hotel ADR', color='orange')
plt.xlabel('Reservation Status Date', fontsize=30)
plt.ylabel('Mean ADR', fontsize=30)
plt.title('City Hotel & Resort Hotel ADR over Time', fontsize=30)
plt.legend(fontsize=20)
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Extract month and year
df['month_year'] = df['reservation_status_date'].dt.to_period('M')

# Group by month_year and is_canceled, then count
monthly_cancellations = df.groupby(['month_year', 'is_canceled']).size().unstack(fill_value=0)

# Plot the double bar graph
plt.figure(figsize=(20, 10))
monthly_cancellations.plot(kind='bar', stacked=False, figsize=(20, 10), color=['red', 'green'])
plt.xlabel('Month-Year', fontsize=30)
plt.ylabel('Number of Reservations', fontsize=30)
plt.title('Cancelled and Not Cancelled Reservations by Month', fontsize=30)
plt.legend(['Not Cancelled', 'Cancelled'], fontsize=20)
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Extract month and year
df['month_year'] = df['reservation_status_date'].dt.to_period('M')

# Filter data for 2016 to 2017 only
filtered_df = df[(df['reservation_status_date'].dt.year >= 2016) & (df['reservation_status_date'].dt.year <= 2017)]

# Group by month_year and is_canceled, then count
monthly_cancellations = filtered_df.groupby(['month_year', 'is_canceled']).size().unstack(fill_value=0)

# Plot the double bar graph
plt.figure(figsize=(20, 10))
monthly_cancellations.plot(kind='bar', stacked=False, figsize=(20, 10), color=['green', 'red'])
plt.xlabel('Month-Year', fontsize=30)
plt.ylabel('Number of Reservations', fontsize=30)
plt.title('Cancelled and Not Cancelled Reservations (2016-2017)', fontsize=30)
plt.legend(['Not Cancelled', 'Cancelled'], fontsize=20)
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Extract month and year
df['month_year'] = df['reservation_status_date'].dt.to_period('M')

# Filter data for 2016 only
filtered_df_2016 = df[df['reservation_status_date'].dt.year == 2016]

# Group by month_year and is_canceled, then count
monthly_cancellations_2016 = filtered_df_2016.groupby(['month_year', 'is_canceled']).size().unstack(fill_value=0)

# Plot the double bar graph with thicker bars and y-axis label in 1000s
plt.figure(figsize=(20, 10))
ax = monthly_cancellations_2016.plot(kind='bar', stacked=False, figsize=(20, 10), color=['green', 'red'], width=0.8)
plt.xlabel('Month-Year', fontsize=30)
plt.ylabel('Number of Reservations (in thousands)', fontsize=30)
plt.title('Cancelled and Not Cancelled Reservations (2016)', fontsize=30)
plt.legend(['Not Cancelled', 'Cancelled'], fontsize=20)
plt.xticks(rotation=45)
ax.set_yticklabels(['{:.0f}'.format(y) for y in ax.get_yticks() / 1000])  # Divide y-ticks by 1000

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Extract month and year
df['month_year'] = df['reservation_status_date'].dt.to_period('M')

# Filter data for 2016 only
filtered_df_2016 = df[df['reservation_status_date'].dt.year == 2016]

# Group by month_year, then calculate mean ADR
monthly_adr_2016 = filtered_df_2016.groupby('month_year')['adr'].mean().reset_index()

# Sort by month_year to ensure proper plotting order
monthly_adr_2016 = monthly_adr_2016.sort_values(by='month_year')

# Plot the mean ADR for 2016 by month
plt.figure(figsize=(20, 10))
plt.plot(monthly_adr_2016['month_year'].astype(str), monthly_adr_2016['adr'], marker='o', color='blue', linestyle='-')
plt.xlabel('Month-Year', fontsize=20)
plt.ylabel('Mean ADR', fontsize=20)
plt.title('Mean ADR by Month in 2016', fontsize=25)
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Extract month and year
df['month_year'] = df['reservation_status_date'].dt.to_period('M')

# Filter data for 2016 only
filtered_df_2016 = df[df['reservation_status_date'].dt.year == 2016]

# Group by month_year, then calculate mean ADR
monthly_adr_2016 = filtered_df_2016.groupby('month_year')['adr'].mean().reset_index()

# Further filter for cancelled reservations in 2016
cancelled_df_2016 = filtered_df_2016[filtered_df_2016['is_canceled'] == 1]

# Group by month_year, then count cancellations
monthly_cancellations_2016 = cancelled_df_2016.groupby('month_year').size().reset_index(name='cancellations')

# Merge the two datasets on month_year
combined_data_adr_cancellations = pd.merge(monthly_adr_2016, monthly_cancellations_2016, on='month_year')

# Plot combined graph
fig, ax1 = plt.subplots(figsize=(20, 10))

# Plot mean ADR
color = 'tab:blue'
ax1.set_xlabel('Month-Year', fontsize=20)
ax1.set_ylabel('Mean ADR', fontsize=20, color=color)
ax1.plot(combined_data_adr_cancellations['month_year'].astype(str), combined_data_adr_cancellations['adr'], marker='o', color=color, linestyle='-', label='Mean ADR')
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis to plot cancellations
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Number of Cancellations', fontsize=20, color=color)
ax2.plot(combined_data_adr_cancellations['month_year'].astype(str), combined_data_adr_cancellations['cancellations'], marker='x', color=color, linestyle='-', label='Cancellations')
ax2.tick_params(axis='y', labelcolor=color)

# Add legends
fig.tight_layout()
ax1.legend(loc='upper left', fontsize=15)
ax2.legend(loc='upper right', fontsize=15)
plt.title('Mean ADR and Cancellations by Month in 2016', fontsize=25)
plt.xticks(rotation=45)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Extract month and year
df['month_year'] = df['reservation_status_date'].dt.to_period('M')

# Filter data for 2016 only
filtered_df_2016 = df[df['reservation_status_date'].dt.year == 2016]

# Group by month_year, then calculate mean ADR
monthly_adr_2016 = filtered_df_2016.groupby('month_year')['adr'].mean().reset_index()

# Group by month_year, then count total bookings
monthly_bookings_2016 = filtered_df_2016.groupby('month_year').size().reset_index(name='bookings')

# Merge the two datasets on month_year
combined_data_adr_bookings = pd.merge(monthly_adr_2016, monthly_bookings_2016, on='month_year')

# Plot combined graph
fig, ax1 = plt.subplots(figsize=(20, 10))

# Plot mean ADR
color = 'tab:red'
ax1.set_xlabel('Month-Year', fontsize=20)
ax1.set_ylabel('Mean ADR', fontsize=20, color=color)
ax1.plot(combined_data_adr_bookings['month_year'].astype(str), combined_data_adr_bookings['adr'], marker='o', color=color, linestyle='-', label='Mean ADR')
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis to plot total bookings
ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Number of Bookings', fontsize=20, color=color)
ax2.plot(combined_data_adr_bookings['month_year'].astype(str), combined_data_adr_bookings['bookings'], marker='x', color=color, linestyle='-', label='Total Bookings')
ax2.tick_params(axis='y', labelcolor=color)

# Add legends
fig.tight_layout()
ax1.legend(loc='upper left', fontsize=15)
ax2.legend(loc='upper right', fontsize=15)
plt.title('Mean ADR and Total Bookings by Month in 2016', fontsize=25)
plt.xticks(rotation=45)

plt.show()

# %%
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Extract month and year
df['month_year'] = df['reservation_status_date'].dt.to_period('M')

# Group by month_year, then calculate mean ADR and total reservations
monthly_adr_reservations = df.groupby('month_year').agg({'adr': 'mean', 'reservation_status_date': 'size'}).rename(columns={'reservation_status_date': 'reservations'}).reset_index()

# Compute the correlation between ADR and total reservations
correlation = monthly_adr_reservations['adr'].corr(monthly_adr_reservations['reservations'])

# Display the correlation coefficient
print(f'Correlation between ADR and Total Reservations: {correlation}')
# Out:
# Correlation between ADR and Total Reservations: 0.18161420504861675

# %%
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Extract month and year
df['month_year'] = df['reservation_status_date'].dt.to_period('M')

# Filter data for City Hotel
city_hotel_data = df[df['hotel'] == 'City Hotel']

# Group by month_year, then calculate mean ADR and total reservations for City Hotel
monthly_adr_reservations_city_hotel = city_hotel_data.groupby('month_year').agg({'adr': 'mean', 'reservation_status_date': 'size'}).rename(columns={'reservation_status_date': 'reservations'}).reset_index()

# Compute the correlation for City Hotel
correlation_city_hotel = monthly_adr_reservations_city_hotel['adr'].corr(monthly_adr_reservations_city_hotel['reservations'])

print(f'Correlation between Mean ADR and Total Reservations for City Hotel: {correlation_city_hotel:.2f}')

# Filter data for Resort Hotel
resort_hotel_data = df[df['hotel'] == 'Resort Hotel']

# Group by month_year, then calculate mean ADR and total reservations for Resort Hotel
monthly_adr_reservations_resort_hotel = resort_hotel_data.groupby('month_year').agg({'adr': 'mean', 'reservation_status_date': 'size'}).rename(columns={'reservation_status_date': 'reservations'}).reset_index()

# Compute the correlation for Resort Hotel
correlation_resort_hotel = monthly_adr_reservations_resort_hotel['adr'].corr(monthly_adr_reservations_resort_hotel['reservations'])

print(f'Correlation between Mean ADR and Total Reservations for Resort Hotel: {correlation_resort_hotel:.2f}')
# Out:
# Correlation between Mean ADR and Total Reservations for City Hotel: 0.52
# Correlation between Mean ADR and Total Reservations for Resort Hotel: -0.16

# %%
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Extract month and year
df['month_year'] = df['reservation_status_date'].dt.to_period('M')

# Filter data for City Hotel in 2016
filtered_df_city_2016 = df[(df['reservation_status_date'].dt.year == 2016) & (df['hotel'] == 'City Hotel')]

# Group by month_year, then calculate mean ADR and total reservations for City Hotel
monthly_adr_reservations_city_2016 = filtered_df_city_2016.groupby('month_year').agg({'adr': 'mean', 'reservation_status_date': 'size'}).rename(columns={'reservation_status_date': 'reservations'}).reset_index()

# Compute the correlation for City Hotel in 2016
correlation_city_2016 = monthly_adr_reservations_city_2016['adr'].corr(monthly_adr_reservations_city_2016['reservations'])

print(f'Correlation between Mean ADR and Total Reservations for City Hotel in 2016: {correlation_city_2016:.2f}')

# Filter data for Resort Hotel in 2016
filtered_df_resort_2016 = df[(df['reservation_status_date'].dt.year == 2016) & (df['hotel'] == 'Resort Hotel')]

# Group by month_year, then calculate mean ADR and total reservations for Resort Hotel
monthly_adr_reservations_resort_2016 = filtered_df_resort_2016.groupby('month_year').agg({'adr': 'mean', 'reservation_status_date': 'size'}).rename(columns={'reservation_status_date': 'reservations'}).reset_index()

# Compute the correlation for Resort Hotel in 2016
correlation_resort_2016 = monthly_adr_reservations_resort_2016['adr'].corr(monthly_adr_reservations_resort_2016['reservations'])

print(f'Correlation between Mean ADR and Total Reservations for Resort Hotel in 2016: {correlation_resort_2016:.2f}')
# Out:
# Correlation between Mean ADR and Total Reservations for City Hotel in 2016: 0.20
# Correlation between Mean ADR and Total Reservations for Resort Hotel in 2016: -0.28

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Extract month and year
df['month_year'] = df['reservation_status_date'].dt.to_period('M')

# Filter data for 2016 only
filtered_df_resort = df[(df['reservation_status_date'].dt.year == 2016) & (df['hotel'] == 'Resort Hotel')]

# Group by month_year, then calculate mean ADR and total bookings for Resort Hotel
monthly_adr_bookings_resort_hotel = filtered_df_resort.groupby('month_year').agg({'adr': 'mean', 'reservation_status_date': 'size'}).rename(columns={'reservation_status_date': 'bookings'}).reset_index()

# Plot combined graph for Resort Hotel
fig, ax1 = plt.subplots(figsize=(27.4, 19.5))

# Plot mean ADR
color = 'tab:red'
ax1.set_xlabel('Month-Year', fontsize=20)
ax1.set_ylabel('Mean ADR', fontsize=20, color=color)
ax1.plot(monthly_adr_bookings_resort_hotel['month_year'].astype(str), monthly_adr_bookings_resort_hotel['adr'], marker='o', color=color, linestyle='-', label='Mean ADR')
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis to plot total bookings
ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Number of Bookings', fontsize=20, color=color)
ax2.plot(monthly_adr_bookings_resort_hotel['month_year'].astype(str), monthly_adr_bookings_resort_hotel['bookings'], marker='x', color=color, linestyle='-', label='Total Bookings')
ax2.tick_params(axis='y', labelcolor=color)

# Add legends
fig.tight_layout()
ax1.legend(loc='upper left', fontsize=45)
ax2.legend(loc='upper right', fontsize=45)
plt.title('Resort Hotel (2016)', fontsize=45)
plt.xticks(rotation=45)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Extract month and year
df['month_year'] = df['reservation_status_date'].dt.to_period('M')

# Filter data for 2016 only
filtered_df_city = df[(df['reservation_status_date'].dt.year == 2016) & (df['hotel'] == 'City Hotel')]

# Group by month_year, then calculate mean ADR and total bookings for City Hotel
monthly_adr_bookings_city_hotel = filtered_df_city.groupby('month_year').agg({'adr': 'mean', 'reservation_status_date': 'size'}).rename(columns={'reservation_status_date': 'bookings'}).reset_index()

# Plot combined graph for City Hotel
fig, ax1 = plt.subplots(figsize=(27.4, 19.5))  # X-axis 1.37 times larger, Y-axis 1.65 times larger

# Plot mean ADR
color = 'tab:red'
ax1.set_xlabel('Month-Year', fontsize=20)
ax1.set_ylabel('Mean ADR', fontsize=20, color=color)
ax1.plot(monthly_adr_bookings_city_hotel['month_year'].astype(str), monthly_adr_bookings_city_hotel['adr'], marker='o', color=color, linestyle='-', label='Mean ADR')
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis to plot total bookings
ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Number of Bookings', fontsize=20, color=color)
ax2.plot(monthly_adr_bookings_city_hotel['month_year'].astype(str), monthly_adr_bookings_city_hotel['bookings'], marker='x', color=color, linestyle='-', label='Total Bookings')
ax2.tick_params(axis='y', labelcolor=color)

# Add legends
fig.tight_layout()
ax1.legend(loc='upper left', fontsize=45)
ax2.legend(loc='upper right', fontsize=45)
plt.title('City Hotel (2016)', fontsize=45)
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# #### Plot the single bar graph with blue color and y-axis labeled in units of 10,000
# plt.figure(figsize=(20, 10))
# ax = plt.bar(monthly_adr_sum_cancelled_2016['month_year'].astype(str), monthly_adr_sum_cancelled_2016['adr'], color='blue', width=0.8)
# plt.xlabel('Month-Year', fontsize=30)
# plt.ylabel('Total ADR (in 10,000s)', fontsize=30)
# plt.title('Total ADR for Cancelled Reservations by Month (2016)', fontsize=30)
# plt.xticks(rotation=45)
#
# # Adjust y-axis labels to show units in 10,000s
# ax = plt.gca()
# ax.set_yticklabels(['{:.0f}'.format(y / 10000) for y in ax.get_yticks()])
#
# plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Extract month and year
df['month_year'] = df['reservation_status_date'].dt.to_period('M')

# Filter data for 2016 only
filtered_df_2016 = df[df['reservation_status_date'].dt.year == 2016]

# Group by month_year, then calculate mean ADR for each month in 2016
monthly_adr_2016 = filtered_df_2016.groupby('month_year')['adr'].mean().reset_index()

# Plot the mean ADR for 2016 by month
plt.figure(figsize=(20, 10))
plt.plot(monthly_adr_2016['month_year'].astype(str), monthly_adr_2016['adr'], marker='o', color='blue', linestyle='-')
plt.xlabel('Month-Year', fontsize=20)
plt.ylabel('Mean ADR', fontsize=20)
plt.title('Mean ADR by Month in 2016', fontsize=25)
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Extract month and year
df['month_year'] = df['reservation_status_date'].dt.to_period('M')

# Filter data for 2016 only
filtered_df_2016 = df[df['reservation_status_date'].dt.year == 2016]

# Group by month_year, then calculate total reservations for each month in 2016
monthly_reservations_2016 = filtered_df_2016.groupby('month_year').size().reset_index(name='reservations')

# Plot the total reservations for 2016 by month
plt.figure(figsize=(20, 10))
plt.plot(monthly_reservations_2016['month_year'].astype(str), monthly_reservations_2016['reservations'], marker='o', color='blue', linestyle='-')
plt.xlabel('Month-Year', fontsize=20)
plt.ylabel('Total Reservations', fontsize=20)
plt.title('Total Reservations by Month in 2016', fontsize=25)
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Filter data for 2016 only
filtered_df_2016 = df[df['reservation_status_date'].dt.year == 2016]

# Calculate the number of reservations by country for 2016 and select the top nine countries
reservations_by_country_2016 = filtered_df_2016['country'].value_counts().head(9)

# Plot the pie chart for reservations by country in 2016 (top 9 countries)
fig, ax = plt.subplots(figsize=(10, 7))
wedges, texts, autotexts = ax.pie(reservations_by_country_2016, startangle=140, autopct='%1.1f%%', pctdistance=0.85)

# Customize labels with arrows and increase font size to 16
labels = reservations_by_country_2016.index

for i, wedge in enumerate(wedges):
    ang = (wedge.theta2 - wedge.theta1)/2 + wedge.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    ax.annotate(labels[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, 
                fontsize=16,  # Increased font size to 16
                arrowprops=dict(arrowstyle="->", connectionstyle=connectionstyle))

plt.title('Reservations by Country in 2016 (Top 9)')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Filter data for 2016 only
filtered_df_2016 = df[df['reservation_status_date'].dt.year == 2016]

# Filter for cancelled reservations in 2016
cancelled_df_2016 = filtered_df_2016[filtered_df_2016['is_canceled'] == 1]

# Calculate the number of cancellations by country for 2016 and select the top nine countries
cancellations_by_country_2016 = cancelled_df_2016['country'].value_counts().head(9)

# Plot the pie chart for cancellations by country in 2016 (top 9 countries)
fig, ax = plt.subplots(figsize=(10, 7))
wedges, texts, autotexts = ax.pie(cancellations_by_country_2016, startangle=140, autopct='%1.1f%%', pctdistance=0.85)

# Customize labels with arrows and increase font size to 16
labels = cancellations_by_country_2016.index

for i, wedge in enumerate(wedges):
    ang = (wedge.theta2 - wedge.theta1)/2 + wedge.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    ax.annotate(labels[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, 
                fontsize=16,  # Increased font size to 16
                arrowprops=dict(arrowstyle="->", connectionstyle=connectionstyle))

plt.title('Cancellations by Country in 2016 (Top 9)')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.show()

# %%
# Calculate the value counts for the market segment column
market_segment_counts = df['market_segment'].value_counts()

# Normalize the value counts
market_segment_normalized = market_segment_counts / market_segment_counts.sum()

# Display the normalized counts
print(market_segment_normalized)
# Out:
# market_segment
# Online TA        0.479108
# Offline TA/TO    0.203747
# Groups           0.167187
# Direct           0.104396
# Corporate        0.043049
# Aviation         0.001975
# Complementary    0.000539
# Name: count, dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Calculate the value counts for the market segment column
market_segment_counts = df['market_segment'].value_counts()

# Plot the pie chart for market segments with labels removed
fig, ax = plt.subplots(figsize=(10, 7))
wedges, texts, autotexts = ax.pie(market_segment_counts, startangle=140, autopct='%1.1f%%', pctdistance=0.85)

# Customize labels with arrows and increase font size to 16
labels = market_segment_counts.index

for i, wedge in enumerate(wedges):
    ang = (wedge.theta2 - wedge.theta1)/2 + wedge.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    ax.annotate(labels[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, 
                fontsize=16,  # Increased font size to 16
                arrowprops=dict(arrowstyle="->", connectionstyle=connectionstyle))

plt.title('Market Segment Distribution')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Filter for cancelled reservations
cancelled_df = df[df['is_canceled'] == 1]

# Calculate the value counts for the market segment column
market_segment_cancelled_counts = cancelled_df['market_segment'].value_counts()

# Plot the bar graph for cancellations by market segment with increased x-axis length
plt.figure(figsize=(21.45, 10))  # Increased x-axis by 1.23 times
plt.bar(market_segment_cancelled_counts.index, market_segment_cancelled_counts.values, color='blue')
plt.xlabel('Market Segment', fontsize=20)
plt.ylabel('Number of Cancellations', fontsize=20)
plt.title('Cancellations by Market Segment', fontsize=25)
plt.xticks(rotation=0, fontsize=16)  # Increased font size to 16 for market segment types
plt.show()

# %%
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Calculate total bookings for each market segment
total_bookings = df['market_segment'].value_counts()

# Filter for cancelled reservations
cancelled_df = df[df['is_canceled'] == 1]

# Calculate total cancellations for each market segment
total_cancellations = cancelled_df['market_segment'].value_counts()

# Compute cancellation rates
cancellation_rate = (total_cancellations / total_bookings) * 100

# Get cancellation rates for "Groups" and "Offline TA/TO"
groups_cancellation_rate = cancellation_rate['Groups']
offline_ta_to_cancellation_rate = cancellation_rate['Offline TA/TO']

# Calculate how much higher the "Groups" cancellation rate is compared to "Offline TA/TO"
difference = groups_cancellation_rate - offline_ta_to_cancellation_rate

# Display the results
print(f'Cancellation Rate for Groups: {groups_cancellation_rate:.2f}%')
print(f'Cancellation Rate for Offline TA/TO: {offline_ta_to_cancellation_rate:.2f}%')
print(f'Groups cancellation rate is {difference:.2f}% higher than Offline TA/TO')
# Out:
# Cancellation Rate for Groups: 61.74%
# Cancellation Rate for Offline TA/TO: 34.58%
# Groups cancellation rate is 27.16% higher than Offline TA/TO

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Filter for cancelled reservations
cancelled_df = df[df['is_canceled'] == 1]

# Calculate the value counts for the market segment column
market_segment_cancelled_counts = cancelled_df['market_segment'].value_counts()

# Plot the pie chart for market segment cancellations with labels removed
fig, ax = plt.subplots(figsize=(10, 7))
wedges, texts, autotexts = ax.pie(market_segment_cancelled_counts, startangle=140, autopct='%1.1f%%', pctdistance=0.85)

# Customize labels with arrows and increase font size to 16
labels = market_segment_cancelled_counts.index

for i, wedge in enumerate(wedges):
    ang = (wedge.theta2 - wedge.theta1)/2 + wedge.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    ax.annotate(labels[i], xy=(x, y), xytext=(1.6*np.sign(x), 1.8*y),
                horizontalalignment=horizontalalignment, 
                fontsize=16,  # Increased font size to 16
                arrowprops=dict(arrowstyle="->", connectionstyle=connectionstyle))

plt.title('Market Segment Cancellations')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Extract month and year
df['year_month'] = df['reservation_status_date'].dt.to_period('M')

# Filter data for 2016 only
filtered_df_2016 = df[df['reservation_status_date'].dt.year == 2016]

# Further filter for cancelled reservations
cancelled_df_2016 = filtered_df_2016[filtered_df_2016['is_canceled'] == 1]

# Group by year_month and market_segment, then count cancellations
monthly_market_segment_cancelled = cancelled_df_2016.groupby(['year_month', 'market_segment']).size().unstack(fill_value=0)

# Plot the bar graph for each month in 2016
monthly_market_segment_cancelled.plot(kind='bar', stacked=True, figsize=(20, 10))
plt.xlabel('Month-Year', fontsize=20)
plt.ylabel('Number of Cancellations', fontsize=20)
plt.title('Cancellations by Market Segment and Month (2016)', fontsize=25)
plt.xticks(rotation=45)
plt.legend(title='Market Segment', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Extract month and year
df['month_year'] = df['reservation_status_date'].dt.to_period('M')

# Filter data for 2016 only
filtered_df_2016 = df[df['reservation_status_date'].dt.year == 2016]

# Further filter for cancelled and non-cancelled reservations in all hotels
cancelled_all_hotels = filtered_df_2016[filtered_df_2016['is_canceled'] == 1]
non_cancelled_all_hotels = filtered_df_2016[filtered_df_2016['is_canceled'] == 0]

# Group by month_year, then count cancellations and non-cancellations
monthly_cancellations_all_hotels = cancelled_all_hotels.groupby('month_year').size().reset_index(name='cancellations')
monthly_non_cancellations_all_hotels = non_cancelled_all_hotels.groupby('month_year').size().reset_index(name='non_cancellations')

# Merge the datasets on month_year
combined_data = pd.merge(monthly_cancellations_all_hotels, monthly_non_cancellations_all_hotels, on='month_year')

# Plot double bar graph
fig, ax = plt.subplots(figsize=(20, 10))
bar_width = 0.4

# Set positions for bars
r1 = range(len(combined_data))
r2 = [x + bar_width for x in r1]

# Plot bars
plt.bar(r1, combined_data['cancellations'], color='red', width=bar_width, label='Cancellations')
plt.bar(r2, combined_data['non_cancellations'], color='green', width=bar_width, label='Non-Cancellations')

# Add labels and title
plt.xlabel('Month-Year', fontsize=30)
plt.ylabel('Number of Reservations', fontsize=30)
plt.title('Cancellations and Non-Cancellations by Month (2016)', fontsize=30)
plt.xticks([r + bar_width/2 for r in range(len(combined_data))], combined_data['month_year'].astype(str), rotation=45)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Extract month and year
df['month_year'] = df['reservation_status_date'].dt.to_period('M')

# Filter data for 2016 only
filtered_df_2016 = df[df['reservation_status_date'].dt.year == 2016]

# Further filter for cancelled and non-cancelled reservations in all hotels
cancelled_all_hotels = filtered_df_2016[filtered_df_2016['is_canceled'] == 1]
non_cancelled_all_hotels = filtered_df_2016[filtered_df_2016['is_canceled'] == 0]

# Group by month_year, then calculate mean ADR for cancelled and non-cancelled
monthly_adr_cancelled_2016 = cancelled_all_hotels.groupby('month_year')['adr'].mean().reset_index()
monthly_adr_non_cancelled_2016 = non_cancelled_all_hotels.groupby('month_year')['adr'].mean().reset_index()

# Merge the datasets on month_year
combined_data_adr = pd.merge(monthly_adr_cancelled_2016, monthly_adr_non_cancelled_2016, on='month_year', suffixes=('_cancelled', '_non_cancelled'))

# Plot double bar graph
fig, ax = plt.subplots(figsize=(20, 10))
bar_width = 0.4

# Set positions for bars
r1 = range(len(combined_data_adr))
r2 = [x + bar_width for x in r1]

# Plot bars
plt.bar(r1, combined_data_adr['adr_cancelled'], color='red', width=bar_width, label='Cancelled')
plt.bar(r2, combined_data_adr['adr_non_cancelled'], color='green', width=bar_width, label='Non-Cancelled')

# Add labels and title
plt.xlabel('Month-Year', fontsize=30)
plt.ylabel('Mean ADR', fontsize=30)
plt.title('Mean ADR for Cancelled and Non-Cancelled Reservations by Month (2016)', fontsize=30)
plt.xticks([r + bar_width/2 for r in range(len(combined_data_adr))], combined_data_adr['month_year'].astype(str), rotation=45)
plt.legend()
plt.show()

# %%
pip install nbconvert
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Create a new column 'reservation_type' based on the 'reservation_status'
df['reservation_type'] = df['reservation_status'].apply(lambda x: 'Cancelled' if x == 'Canceled' else ('No-show' if x == 'No-show' else 'Not Cancelled'))

# Group the data by 'reservation_type' and get counts for each type
reservation_type_counts = df['reservation_type'].value_counts()

# Display the grouped data
print("Counts of Reservation Types:")
print(reservation_type_counts)
# Out:
# Counts of Reservation Types:
# reservation_type
# Not Cancelled    74186
# Cancelled        42773
# Name: count, dtype: int64

# %%
import pandas as pd

# Group the data by 'reservation_status' and get counts for each type
reservation_status_counts = df['reservation_status'].value_counts()

# Display the counts for each reservation status type
print("Counts of each Reservation Status:")
print(reservation_status_counts)
# Out:
# Counts of each Reservation Status:
# reservation_status
# Check-Out    73009
# Canceled     42773
# No-Show       1177
# Name: count, dtype: int64

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 6       Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2                    July                        27
# 3                    July                        27
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure the date column is in datetime format
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# Filter for 'No-show' reservations
no_show_df = df[df['reservation_status'] == 'No-show']

# Group by year, then count the no-show reservations
yearly_no_show = no_show_df['reservation_status_date'].dt.year.value_counts().sort_index()

# Plot the graph for no-show reservations by year
plt.figure(figsize=(20, 10))
plt.plot(yearly_no_show.index, yearly_no_show.values, marker='o', color='red', linestyle='-')
plt.xlabel('Year', fontsize=20)
plt.ylabel('Number of No-show Reservations', fontsize=20)
plt.title('No-show Reservations by Year', fontsize=25)
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
